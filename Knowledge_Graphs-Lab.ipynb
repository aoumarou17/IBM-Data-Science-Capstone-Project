# %% [markdown]
# An Introduction to Natural Language Processing with Python for SEOs
#
# We are going to learn practical NLP while building a simple knowledge graph from scratch.
#
# We are going to extract useful facts automatically from SEJ XML sitemaps.
#
# In order to do this and keep things simple and fast, we will pull article headlines from the URLs in the XML sitemaps.
#
# We will extract entities of interest and their relationships from the headlines.
#
# Finally, we will build a powerful knowledge graph and visualize the most popular relationships.
#
# Here is the technical plan:
#
# 1. We will fetch all SEJ XML sitemaps
# 2. We will parse the URLs to extract the headlines in their slugs
# 3. We will extract entity pairs from the headlines
# 4. We will extract corresponding relationships
# 5. We will build a knowledge graph and a simple form to visualize specific relationships
#
# Resources to learn more

# %% [markdown]
# ##Fetching all SEJ XML sitemaps
#
# We recently did a webinar with Elias from The Money Supermarket and learned about his wonderful Python library for marketers: advertools.
#
# Some of my old articles are not working with the newer library versions. He gave me a good idea to print the library versions so it is easy to get the code to work.

# %%
# %%capture
# !pip install advertools

# %%
import advertools as adv
print(adv.__version__)
# Out:
# 0.13.5

# %%
sitemap_url = "https://www.searchenginejournal.com/sitemap_index.xml" #@param {type:"string"}

# %% [markdown]
# Let's download the sitemap index

# %%
df = adv.sitemap_to_df(sitemap_url)
# Out:
# 2024-02-15 12:31:47,438 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap3.xml
# 2024-02-15 12:31:47,446 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap2.xml
# 2024-02-15 12:31:47,461 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap.xml
# 2024-02-15 12:31:47,487 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap4.xml
# 2024-02-15 12:31:47,496 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap7.xml
# 2024-02-15 12:31:47,565 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap8.xml
# 2024-02-15 12:31:47,593 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap6.xml
# 2024-02-15 12:31:47,618 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap5.xml
# 2024-02-15 12:31:48,261 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap12.xml
# 2024-02-15 12:31:48,285 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap10.xml
# 2024-02-15 12:31:48,285 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap9.xml
# 2024-02-15 12:31:48,310 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap11.xml
# 2024-02-15 12:31:48,357 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap13.xml
# 2024-02-15 12:31:48,376 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap15.xml
# 2024-02-15 12:31:48,383 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap14.xml
# 2024-02-15 12:31:48,396 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap16.xml
# 2024-02-15 12:31:49,060 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap17.xml
# 2024-02-15 12:31:49,125 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap18.xml
# 2024-02-15 12:31:49,144 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap20.xml
# 2024-02-15 12:31:49,159 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap24.xml
# 2024-02-15 12:31:49,176 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap19.xml
# 2024-02-15 12:31:49,223 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap23.xml
# 2024-02-15 12:31:49,231 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap21.xml
# 2024-02-15 12:31:49,261 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/post-sitemap22.xml
# 2024-02-15 12:31:49,555 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/page-sitemap.xml
# 2024-02-15 12:31:49,590 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/google-algo-history-sitemap.xml
# 2024-02-15 12:31:49,602 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/content-kpis-sitemap.xml
# 2024-02-15 12:31:49,614 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/seo-tools-sitemap.xml
# 2024-02-15 12:31:49,627 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/link-building-guide-sitemap.xml
# 2024-02-15 12:31:49,633 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/seo-guide-sitemap.xml
# 2024-02-15 12:31:49,652 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/local-seo-sitemap.xml
# 2024-02-15 12:31:49,668 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/ppc-guide-sitemap.xml
# 2024-02-15 12:31:49,950 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/on-page-seo-sitemap.xml
# 2024-02-15 12:31:49,975 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/ecommerce-guide-sitemap.xml
# 2024-02-15 12:31:49,989 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/holiday-marketing-sitemap.xml
# 2024-02-15 12:31:50,016 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/technical-seo-sitemap.xml
# 2024-02-15 12:31:50,028 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/social-media-guide-sitemap.xml
# 2024-02-15 12:31:50,053 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/search-engines-sitemap.xml
# 2024-02-15 12:31:50,067 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/content-marketing-sitemap.xml
# 2024-02-15 12:31:50,074 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/seo-audit-sitemap.xml
# 2024-02-15 12:31:50,322 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/law-firm-seo-sitemap.xml
# 2024-02-15 12:31:50,365 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/core-web-vitals-sitemap.xml
# 2024-02-15 12:31:50,396 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/enterprise-seo-sitemap.xml
# 2024-02-15 12:31:50,407 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/google-eat-sitemap.xml
# 2024-02-15 12:31:50,419 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/facebook-ads-sitemap.xml
# 2024-02-15 12:31:50,436 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/wordpress-seo-sitemap.xml
# 2024-02-15 12:31:50,442 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/keyword-research-sitemap.xml
# 2024-02-15 12:31:50,568 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/ranking-factors-sitemap.xml
# 2024-02-15 12:31:50,674 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/seo-trends-sitemap.xml
# 2024-02-15 12:31:50,712 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/category-sitemap.xml
# 2024-02-15 12:31:50,759 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/news-sitemap.xml
# 2024-02-15 12:31:50,840 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/author-sitemap2.xml
# 2024-02-15 12:31:50,989 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.searchenginejournal.com/author-sitemap.xml

# %% [markdown]
# One cool feature in the package is that it downloaded all the linked sitemaps in the index and we get a nice dataframe
#
# ---

# %%
df
# Out:
#                                                      loc  \
# 0      https://www.searchenginejournal.com/dick-chene...
# 1      https://www.searchenginejournal.com/internet-e...
# 2      https://www.searchenginejournal.com/launch-fir...
# 3      https://www.searchenginejournal.com/search-eng...
# 4      https://www.searchenginejournal.com/targetcom-...
# ...                                                  ...
# 24206  https://www.searchenginejournal.com/author/ann...
# 24207  https://www.searchenginejournal.com/author/bre...
# 24208  https://www.searchenginejournal.com/author/cla...
# 24209  https://www.searchenginejournal.com/author/adc...
# 24210  https://www.searchenginejournal.com/author/bre...
#
#                         lastmod image image_loc  \
# 0     2006-02-13 04:24:36+00:00   NaN       NaN
# 1     2006-02-13 06:02:56+00:00   NaN       NaN
# 2     2006-02-13 06:55:50+00:00   NaN       NaN
# 3     2006-02-13 07:32:03+00:00   NaN       NaN
# 4     2006-02-13 15:33:15+00:00   NaN       NaN
# ...                         ...   ...       ...
# 24206 2022-08-20 13:44:45+00:00   NaN       NaN
# 24207 2022-08-20 13:44:45+00:00   NaN       NaN
# 24208 2022-08-20 13:44:45+00:00   NaN       NaN
# 24209 2022-08-20 13:44:45+00:00   NaN       NaN
# 24210 2022-08-20 13:44:45+00:00   NaN       NaN
#
#                                                  sitemap  \
# 0      https://www.searchenginejournal.com/post-sitem...
# 1      https://www.searchenginejournal.com/post-sitem...
# 2      https://www.searchenginejournal.com/post-sitem...
# 3      https://www.searchenginejournal.com/post-sitem...
# 4      https://www.searchenginejournal.com/post-sitem...
# ...                                                  ...
# 24206  https://www.searchenginejournal.com/author-sit...
# 24207  https://www.searchenginejournal.com/author-sit...
# 24208  https://www.searchenginejournal.com/author-sit...
# 24209  https://www.searchenginejournal.com/author-sit...
# 24210  https://www.searchenginejournal.com/author-sit...
#
#           sitemap_last_modified  sitemap_size_mb  \
# 0     2024-02-15 10:29:51+00:00         0.155574
# 1     2024-02-15 10:29:51+00:00         0.155574
# 2     2024-02-15 10:29:51+00:00         0.155574
# 3     2024-02-15 10:29:51+00:00         0.155574
# 4     2024-02-15 10:29:51+00:00         0.155574
# ...                         ...              ...
# 24206 2024-02-15 10:06:16+00:00         0.126728
# 24207 2024-02-15 10:06:16+00:00         0.126728
# 24208 2024-02-15 10:06:16+00:00         0.126728
# 24209 2024-02-15 10:06:16+00:00         0.126728
# 24210 2024-02-15 10:06:16+00:00         0.126728
#
#                          download_date news news_publication publication_name  \
# 0     2024-02-15 10:31:47.462626+00:00  NaN              NaN              NaN
# 1     2024-02-15 10:31:47.462626+00:00  NaN              NaN              NaN
# 2     2024-02-15 10:31:47.462626+00:00  NaN              NaN              NaN
# 3     2024-02-15 10:31:47.462626+00:00  NaN              NaN              NaN
# 4     2024-02-15 10:31:47.462626+00:00  NaN              NaN              NaN
# ...                                ...  ...              ...              ...
# 24206 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 24207 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 24208 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 24209 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 24210 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
#
#       publication_language news_publication_date news_title
# 0                      NaN                   NaN        NaN
# 1                      NaN                   NaN        NaN
# 2                      NaN                   NaN        NaN
# 3                      NaN                   NaN        NaN
# 4                      NaN                   NaN        NaN
# ...                    ...                   ...        ...
# 24206                  NaN                   NaN        NaN
# 24207                  NaN                   NaN        NaN
# 24208                  NaN                   NaN        NaN
# 24209                  NaN                   NaN        NaN
# 24210                  NaN                   NaN        NaN
#
# [24211 rows x 14 columns]

# %% [markdown]
# Look how simple it is to filter articles/pages from this year. We have 1550 articles

# %%
df[df["lastmod"] > '2023-12-31']
# Out:
#                                                      loc  \
# 1899                https://www.searchenginejournal.com/
# 18449  https://www.searchenginejournal.com/tree-of-th...
# 18450  https://www.searchenginejournal.com/john-muell...
# 18451  https://www.searchenginejournal.com/stock-phot...
# 18452  https://www.searchenginejournal.com/google-on-...
# ...                                                  ...
# 23215  https://www.searchenginejournal.com/author/lee...
# 23216  https://www.searchenginejournal.com/author/ale...
# 23217  https://www.searchenginejournal.com/author/and...
# 23218  https://www.searchenginejournal.com/author/don...
# 23219  https://www.searchenginejournal.com/author/ahr...
#
#                         lastmod     image  \
# 1899  2024-02-14 21:39:34+00:00       NaN
# 18449 2024-01-01 05:55:28+00:00  \n\t\t\t
# 18450 2024-01-01 08:36:10+00:00  \n\t\t\t
# 18451 2024-01-01 08:41:16+00:00  \n\t\t\t
# 18452 2024-01-01 08:49:50+00:00  \n\t\t\t
# ...                         ...       ...
# 23215 2024-01-29 06:30:34+00:00       NaN
# 23216 2024-01-18 12:22:51+00:00       NaN
# 23217 2024-01-04 12:45:29+00:00       NaN
# 23218 2024-01-04 12:38:18+00:00       NaN
# 23219 2024-01-03 15:10:56+00:00       NaN
#
#                                                image_loc  \
# 1899                                                 NaN
# 18449  https://www.searchenginejournal.com/wp-content...
# 18450  https://www.searchenginejournal.com/wp-content...
# 18451  https://www.searchenginejournal.com/wp-content...
# 18452  https://www.searchenginejournal.com/wp-content...
# ...                                                  ...
# 23215                                                NaN
# 23216                                                NaN
# 23217                                                NaN
# 23218                                                NaN
# 23219                                                NaN
#
#                                                  sitemap  \
# 1899   https://www.searchenginejournal.com/post-sitem...
# 18449  https://www.searchenginejournal.com/post-sitem...
# 18450  https://www.searchenginejournal.com/post-sitem...
# 18451  https://www.searchenginejournal.com/post-sitem...
# 18452  https://www.searchenginejournal.com/post-sitem...
# ...                                                  ...
# 23215  https://www.searchenginejournal.com/author-sit...
# 23216  https://www.searchenginejournal.com/author-sit...
# 23217  https://www.searchenginejournal.com/author-sit...
# 23218  https://www.searchenginejournal.com/author-sit...
# 23219  https://www.searchenginejournal.com/author-sit...
#
#           sitemap_last_modified  sitemap_size_mb  \
# 1899  2024-02-15 09:55:52+00:00         0.134017
# 18449 2024-02-15 09:45:55+00:00         0.390761
# 18450 2024-02-15 09:45:55+00:00         0.390761
# 18451 2024-02-15 09:45:55+00:00         0.390761
# 18452 2024-02-15 09:45:55+00:00         0.390761
# ...                         ...              ...
# 23215 2024-02-15 10:06:16+00:00         0.126728
# 23216 2024-02-15 10:06:16+00:00         0.126728
# 23217 2024-02-15 10:06:16+00:00         0.126728
# 23218 2024-02-15 10:06:16+00:00         0.126728
# 23219 2024-02-15 10:06:16+00:00         0.126728
#
#                          download_date news news_publication publication_name  \
# 1899  2024-02-15 10:31:47.480078+00:00  NaN              NaN              NaN
# 18449 2024-02-15 10:31:49.167702+00:00  NaN              NaN              NaN
# 18450 2024-02-15 10:31:49.167702+00:00  NaN              NaN              NaN
# 18451 2024-02-15 10:31:49.167702+00:00  NaN              NaN              NaN
# 18452 2024-02-15 10:31:49.167702+00:00  NaN              NaN              NaN
# ...                                ...  ...              ...              ...
# 23215 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 23216 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 23217 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 23218 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
# 23219 2024-02-15 10:31:51.013028+00:00  NaN              NaN              NaN
#
#       publication_language news_publication_date news_title
# 1899                   NaN                   NaN        NaN
# 18449                  NaN                   NaN        NaN
# 18450                  NaN                   NaN        NaN
# 18451                  NaN                   NaN        NaN
# 18452                  NaN                   NaN        NaN
# ...                    ...                   ...        ...
# 23215                  NaN                   NaN        NaN
# 23216                  NaN                   NaN        NaN
# 23217                  NaN                   NaN        NaN
# 23218                  NaN                   NaN        NaN
# 23219                  NaN                   NaN        NaN
#
# [227 rows x 14 columns]

# %%
df[df["lastmod"] > '2020-01-01'][["loc", "lastmod"]].to_csv("latest_articles.csv", index=False)

# %% [markdown]
# We can export this list to a csv. I will include only the URL and last modification time stamp.
#
# If you click on the file folder to the left, you will see the file and you can right click to download it.

# %% [markdown]
# ##Extract headlines from the URLs
#
# The advertools library has a function to break URLs, but let's do it manually to get familiar with the process.

# %%
example_url="https://www.searchenginejournal.com/google-be-careful-relying-on-3rd-parties-to-render-website-content/376547/" #@param {type:"string"}

# %%
from urllib.parse import urlparse
import re

# %%
u = urlparse(example_url)

# %%
u
# Out:
# ParseResult(scheme='https', netloc='www.searchenginejournal.com', path='/google-be-careful-relying-on-3rd-parties-to-render-website-content/376547/', params='', query='', fragment='')

# %% [markdown]
# Here we get a named tuple, ```ParseResult```, with a breakdown of the URL components.
#
# We are interested in the ```path```.
#
# We are going to use a simple regex to split it by / and - characters

# %%
slug = re.split("[/-]", u.path)

slug
# Out:
# ['',
#  'google',
#  'be',
#  'careful',
#  'relying',
#  'on',
#  '3rd',
#  'parties',
#  'to',
#  'render',
#  'website',
#  'content',
#  '376547',
#  '']

# %% [markdown]
# Next, we can convert it back to a string

# %%
headline = " ".join(slug)
headline
# Out:
# ' google be careful relying on 3rd parties to render website content 376547 '

# %% [markdown]
# The slugs contain a page identifier that is useless for us. We will remove with a regex

# %%
headline = re.sub("\d{6}", "",headline)
headline
# Out:
# ' google be careful relying on 3rd parties to render website content  '

# %% [markdown]
# Strip whitespace at the borders

# %%
headline = headline.strip()
headline
# Out:
# 'google be careful relying on 3rd parties to render website content'

# %%
if re.match("author|category", "autho stephen kenwright"):
  print("Ok")

# %% [markdown]
# We can convert this code to a function and create a new column in our dataframe

# %%
def get_headline(url):

  u = urlparse(url)

  if len(u.path) > 1:

    slug = re.split("[/-]", u.path)

    new_headline = re.sub("\d{6}", ""," ".join(slug)).strip()

    #skip author and category pages
    if not re.match("author|category", new_headline):
      return new_headline

  return ""

# %%
#let's test it
get_headline(example_url)
# Out:
# 'google be careful relying on 3rd parties to render website content'

# %%
import pandas as pd

#skip the home page and headers
new_df = pd.read_csv("latest_articles.csv", names=["url", "lastmod"], skiprows=2)

# %%
new_df
# Out:
#                                                     url  \
# 0     https://www.searchenginejournal.com/google-how...
# 1     https://www.searchenginejournal.com/track-offl...
# 2     https://www.searchenginejournal.com/do-ugly-si...
# 3     https://www.searchenginejournal.com/youtubes-c...
# 4     https://www.searchenginejournal.com/googles-jo...
# ...                                                 ...
# 8331  https://www.searchenginejournal.com/author/ann...
# 8332  https://www.searchenginejournal.com/author/bre...
# 8333  https://www.searchenginejournal.com/author/cla...
# 8334  https://www.searchenginejournal.com/author/adc...
# 8335  https://www.searchenginejournal.com/author/bre...
#
#                         lastmod
# 0     2020-01-06 11:23:40+00:00
# 1     2020-01-07 12:45:50+00:00
# 2     2020-01-06 21:55:09+00:00
# 3     2020-01-07 04:53:50+00:00
# 4     2020-01-07 11:16:20+00:00
# ...                         ...
# 8331  2022-08-20 13:44:45+00:00
# 8332  2022-08-20 13:44:45+00:00
# 8333  2022-08-20 13:44:45+00:00
# 8334  2022-08-20 13:44:45+00:00
# 8335  2022-08-20 13:44:45+00:00
#
# [8336 rows x 2 columns]

# %% [markdown]
# Let's create a new column named headline

# %%
new_df["url"]
# Out:
# 0       https://www.searchenginejournal.com/google-how...
# 1       https://www.searchenginejournal.com/track-offl...
# 2       https://www.searchenginejournal.com/do-ugly-si...
# 3       https://www.searchenginejournal.com/youtubes-c...
# 4       https://www.searchenginejournal.com/googles-jo...
#                               ...
# 8331    https://www.searchenginejournal.com/author/ann...
# 8332    https://www.searchenginejournal.com/author/bre...
# 8333    https://www.searchenginejournal.com/author/cla...
# 8334    https://www.searchenginejournal.com/author/adc...
# 8335    https://www.searchenginejournal.com/author/bre...
# Name: url, Length: 8336, dtype: object

# %% [markdown]
# this will run the function on each URL

# %%
new_df["url"].apply(lambda x: get_headline(x))
# Out:
# 0                          google how to seo podcast site
# 1         track offline conversions microsoft advertising
# 2                                      do ugly sites sell
# 3       youtubes coppa changes begin today possibly af...
# 4       googles john mueller our seos have it harder t...
#                               ...
# 8331
# 8332
# 8333
# 8334
# 8335
# Name: url, Length: 8336, dtype: object

# %%
new_df["headline"] = new_df["url"].apply(lambda x: get_headline(x))

# %%
new_df
# Out:
#                                                     url  \
# 0     https://www.searchenginejournal.com/google-how...
# 1     https://www.searchenginejournal.com/track-offl...
# 2     https://www.searchenginejournal.com/do-ugly-si...
# 3     https://www.searchenginejournal.com/youtubes-c...
# 4     https://www.searchenginejournal.com/googles-jo...
# ...                                                 ...
# 8331  https://www.searchenginejournal.com/author/ann...
# 8332  https://www.searchenginejournal.com/author/bre...
# 8333  https://www.searchenginejournal.com/author/cla...
# 8334  https://www.searchenginejournal.com/author/adc...
# 8335  https://www.searchenginejournal.com/author/bre...
#
#                         lastmod  \
# 0     2020-01-06 11:23:40+00:00
# 1     2020-01-07 12:45:50+00:00
# 2     2020-01-06 21:55:09+00:00
# 3     2020-01-07 04:53:50+00:00
# 4     2020-01-07 11:16:20+00:00
# ...                         ...
# 8331  2022-08-20 13:44:45+00:00
# 8332  2022-08-20 13:44:45+00:00
# 8333  2022-08-20 13:44:45+00:00
# 8334  2022-08-20 13:44:45+00:00
# 8335  2022-08-20 13:44:45+00:00
#
#                                                headline
# 0                        google how to seo podcast site
# 1       track offline conversions microsoft advertising
# 2                                    do ugly sites sell
# 3     youtubes coppa changes begin today possibly af...
# 4     googles john mueller our seos have it harder t...
# ...                                                 ...
# 8331
# 8332
# 8333
# 8334
# 8335
#
# [8336 rows x 3 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       8336 non-null   object
#  1   lastmod   8336 non-null   object
#  2   headline  8336 non-null   object
# dtypes: object(3)
# memory usage: 195.5+ KB

# %% [markdown]
# ## Extracting named entities

# %% [markdown]
# Let's get our list of headlines and convert to a single text document

# %%
new_df["headline"].tolist()[:10]
# Out:
# ['google how to seo podcast site',
#  'track offline conversions microsoft advertising',
#  'do ugly sites sell',
#  'youtubes coppa changes begin today possibly affecting creator revenue',
#  'googles john mueller our seos have it harder than others',
#  'seo struggles',
#  'challenge google ads trademark disputes',
#  'best amp wordpress plugins',
#  'chrome push notification blocker',
#  'google assistant now has 500 million users worldwide']

# %%
text = "\n".join([x for x in new_df["headline"].tolist() if len(x) > 0])

# %%
with open("text.txt", "w") as f:
  f.write(text)

# %%
print(text)
# Out:
# google how to seo podcast site
# track offline conversions microsoft advertising
# do ugly sites sell
# youtubes coppa changes begin today possibly affecting creator revenue
# googles john mueller our seos have it harder than others
# seo struggles
# challenge google ads trademark disputes
# best amp wordpress plugins
# chrome push notification blocker
# google assistant now has 500 million users worldwide
# track organic conversions
# seo reports which metrics matter how to use them well
# google optimization score ppc
# twitter rolls out a new ad unit in the explore tab
# b2b paid advertising greg finn podcast
# instagram user growth drops to lower levels than previously expected
# female marketers
# facebook pages to redesign good for the advertiser 8875
# quality raters guidelines ranking signals
# stepping into the unknown
# facebook is preparing to launch a desktop redesign to all users
# duckduckgo is now a default search engine option on android in the eu
# actionable tasking seo answer important questions
# biggest link building misconceptions
# googles hogging half your traffic how to get it back
# inspiring instagram contests
# waze local paid marketing
# google ads introduces bid simulator support for smart bidding
# are modal popups searchable
# introduction to python seo spreadsheets
# seo platform wishlist
# user behavior tracking tools
# google january 2020 core update is rolling out imminently
# google ads makes parallel tracking mandatory for video campaigns
# pinterest overtakes snapchat in popularity among us users
# youtube organic visibility google serps
# first party data ppc
# seos are in high demand according to linkedins data
# google introduces a new shopping section in search results
# tony wright better know an seo podcast
# linkedin brings 3 new features to linkedin pages
# snapchat facts
# tips get pinterest followers
# google structured data has no impact on ranking in web search
# youtube shows users comment history in new profile cards
# new baby seo agency same time
# google changes the look of paid and organic search results on desktop
# instagram drops igtv button due to lack of use
# publish content com co uk websites
# a new search engine enters the market onesearch from verizon media
# machine learning spam in google
# google desktop search results marketing oclock podcast
# brand identity
# googles john mueller on optimizing images for search results
# marketing website accessibility assumptions
# how to evaluate link opportunities
# google data vocabulary structured data
# growing organic traffic by 50k monthly visitors case study
# wordpress schema plugins
# googles john mueller recommends less than 5 hops per redirect chain
# googles john mueller one violation will not result in a manual action
# ryan jones better know an seo podcast
# yelp seo optimize listing rank higher
# mindful digital marketing
# googles new dataset search engine comes out of beta
# seo web design
# twitter users can now react to direct messages with emojis
# google makes it easy to revisit similar pages from your search history
# chrome devtools technical seo audits
# google deduplicate featured snippets marketing oclock podcast
# docuseries content strategy
# google featured snippets guidance
# seo for holidays strategy
# duckduckgo adds quick answers to search results
# google web pages in featured snippets not repeated in organic listings
# google responds to criticism regarding desktop search changes
# byte a 6 second looping video app launches on ios and android
# stock photo libraries link building
# how to overcome technical seo issues on a budget
# auditing qa gdn youtube
# use of content marketing campaigns expected to grow in 2020
# googles featured snippet changes impact on organic traffic study
# google makes it possible to temporarily remove sites from search results
# bing implements ux change to reduce missed clicks
# google recommends hiring seos in new search for beginners video
# drive quality calls paid search
# measure success ppc campaigns
# all google ads campaigns to utilize standard delivery as of may 2020
# optimize twitter for business
# content marketing mistakes
# improve skyscraper content
# microsoft advertising updates responsive search ads improved reports more
# marketing analytics tool jumpshot to shut down amid privacy concerns
# managing seo for non seos tips
# dealing with pressure
# hidden hreflang challenges
# google launches sos alert for searches related to coronavirus
# complex seo problems how to fix
# strategy to boost traffic
# 8 ways to become a great seo consultant
# byte video app marketing oclock podcast
# botify unlock hidden seo potential
# just 45 of seo specialists feel their job is secure
# google link penalty reconsideration
# websites optimized for mobile 52638
# wordpress 5 4 lazy loading
# microsoft lists seo as the most important hard skill for marketers
# url capitalization seo
# optimize website tiny niche
# marketing automation data contradictory elements
# google search console fixes issue with tag manager sites may need to re verify
# sempo officially ends
# 12 alternative ppc books every ppc marketer needs to own
# viral reddit images
# shelly fagin podcast interview
# graphic design tips non designers
# tools for ppc managers
# pixel facebook group members
# google maps updated with new icon new features
# ccpa
# google is expanding shopping ads to gmail
# google lets iphone users conduct searches with siri
# google search console index coverage report guide
# better product group management scripts more microsoft shopping campaigns
# google shopping ads in gmail this weeks digital marketing news
# google ads message extensions marketing oclock podcast
# new report reveals the 3 trends shaping email marketing in 2020
# techseoboost 2019 takeaways
# paid media privacy
# things not to do on social media
# linkedin advertising unique
# new instagram feature helps users clean up their following list
# how to build links advice
# google chrome expands ad blocking efforts to ads within videos
# beat big brands seo
# google to discontinue classic version of youtube on desktop
# microsoft advertising introduces new features for shopping campaigns
# google search console begins reporting on review ratings markup
# google explains how to rank
# citations local seo guide
# paid social channels
# googles john mueller there is no benchmark for crawl budget
# study finds virtual assistants are getting worse at answering questions correctly
# google favor gov edu sites
# domains ending in com to reportedly get more expensive
# harley quinn name change
# marketing top tools guilt shame fear
# google 6 need states drive search behavior
# word count for seo
# more content better worse
# googles seo best practices summed up in new video
# gif engine optimization geo
# google ads makes it easier to review a campaigns change history
# log file insights crawl budget optimization
# whats wrong with google search
# google adsense testing advertise here link on sites 2272
# find date google associates to url
# facebook whores for seo smo and sem awareness best search marketing facebook group of 2007 6186
# dosh dosh best social media optimization blog of 2007 6185
# empire today how to optimize a badly branded google results page 6143
# hackers hurting seo
# digital nomad life
# keyword mapping data studio
# why author reputation matters for search
# local seo for enterprise sites from 2004 to 2019
# how to optimize amp stories for google search results
# nofollow anchor text
# google new partner program requirements marketing oclock podcast
# introduction modern javascript for seo
# google partners program puts new requirements on companies
# google confirms no core algorithm update
# link building campaign adaptive framework
# google uses unsupported structured data
# put marketing back in content marketing
# reduce shopping cart abandonment
# make smart bidding smarter
# diversify digital marketing
# google ads makes it easy to share audience lists across accounts
# bert algorithm seo
# marketing couples work love family
# site audit low word count
# youtube is testing a new way for creators to make money from viewers
# google partners change moral dilemma
# seo javascript good bad uncertainty
# sponsored products walmart media group
# google on dealing with manual actions reconsideration requests
# bing webmaster tools gets refreshed with new design new features
# google is testing amp results in desktop serps
# google search console change of address
# what google partners changes mean for agencies clients podcast
# how to keep your business going after a loved one kills themselves
# google to highlight image licensing information in image search results
# subdomain subdirectory cctld
# ppc keyword research
# youtube algorithm findings
# googles john mueller cautions against overuse of multi language content
# alternative link building tactics
# introducing ask me anything about ppc
# new conversion actions in google ads this weeks digital marketing news podcast
# google featured snippet update causalimpact
# twitter makes it easier to append tweets to other tweets
# snapchats new ad unit prompts users to call or text businesses
# google displays prominent links to third party services in local serps
# adsense blocking options
# heres how google develops adsense policies
# google adsense misrepresentative content
# how amp affects publishers advertisers
# asktheadsenseguy how adsense affects seo and the valuable inventory policy update
# john brown on adsense policies reinstatment asktheadsenseguy
# asktheadsenseguy proper adsense implementation content
# asktheadsenseguy
# asktheadsenseguy effective mobile ads and handling adblockers
# linkedin lets users showcase samples of work on their profiles
# 5 easy tips to skyrocket your instagram marketing this year
# googles john mueller to investigate deceitful link building practices
# nofollow crawl indexing update
# data visualizations
# blog comments link building
# facebooks new creator studio app helps with managing pages on the go
# google search console sending email alerts for spikes in search traffic
# november 2019 update recovery
# become influencer on linkedin
# google chrome update introduces a new type of privacy concern
# google other search engines found indexing links to private whatsapp groups
# podcasting tips getting started
# not provided 5 years later
# do keywords matter
# google bert content strategy
# how to find converting keywords and put them to work 41029
# how and when to diversify your anchor text 51425
# link building interview with ontolos garrett french and ben wills 20610
# 3 creative ways to drive more traffic to old blog posts 24279
# ltv cpa
# roi driven seo 3 powerful tips to effectively convert your seo traffic 41877
# seo efforts don%e2%80%99t have to be dead on arrival 38603
# top 3 google factors
# 5 targets set beginning seo campaign
# targeting multiple audiences
# structure ppc campaign automation
# content campaign process insane roi
# site structure migrating to adobe experience manager
# google updates image search with icons for products recipes videos
# amazon retail analytics premium data free
# seo bug vs feature request
# google search console export data
# before you accept guest posts
# how to identify a possible negative seo campaign
# googles advice on how to hire an seo
# affiliate marketing trends crazy pr stunts dropping f bombs with adam riemer podcast
# google lets site owners test preview how to markup on smart displays
# finding the right medication
# essential optimizations modernize your website
# google lets people customize their profile cards for search results
# enhanced bing webmaster tools marketing oclock podcast
# google reasons site traffic declines
# googles seo best practices for news publishers
# google appoints first ever creator liaison for youtube
# twitter gives businesses advice on writing more effective tweets
# linkedin will soon get an instagram like stories feature
# facebooks updated best practices for business to customer messaging
# google discourages repetitive use of faq structured data markup
# pinterest reaches 60 of us women heres what theyre searching for
# amazon sponsored product ads are rising in price new report says
# facebook lets users turn any 2d image into a 3d photo
# google featured snippets guide
# guest post manual actions
# google challenges moz article
# pagination seo 2
# use location data outsmart competitors win market share
# which web design platform is right for you
# mobile first success
# new seo client start relationship
# zero click searches how to get back your lost traffic
# amazon seller strategies
# link building approach
# facebook is rolling out a faster and simpler version of messenger
# most people still in 2020 arent aware facebook owns instagram
# google ads mobile app updated with new features and dark mode
# make responsive search ads work for you
# customer journey seo
# bing healthcare search strategy
# youtube updates mid roll ads editor and notification analytics
# youtube analytics compare metrics
# lets encrypt bug
# blog strategy storytelling usp sales
# twitter stories fleets
# 8 popular wordpress plugins are currently being exploited by hackers
# seo tasks automate with python
# google only worry about sitemaps if your site meets this criteria
# dealing with grief running a business
# social media visual strategy tips
# google ads introduces new reports removes combines old ones
# google says 70 of sites have been moved to mobile first indexing
# ssl certificate merged domains
# unnatural links
# enterprise seo opportunities
# facebook sues namecheap
# stories are coming to twitter with fleets this weeks digital marketing news podcast
# process for understanding site performance automating speed testing
# what is ethical ppc
# site structure internal linking seo
# why using conversions imported from analytics to google ads does not actually make sense
# google to review photos videos uploaded to google my business
# google provides guidance to businesses affected by coronavirus
# tips handling negative customer reviews online
# after launching ecommerce website
# audience analysis seo
# how to make qa videos
# google ads expands portfolio bid strategies with more options
# reddit launches a twitter like ad unit trending takeovers
# brent csutoras social media evolution search engine journal persona journey podcast
# google featured snippets stealing clicks
# match type changes campaign structure choices
# getting the most from customer testimonials with davis nguyen podcast
# brand protection tactics
# google facebook ban ads for face masks as coronavirus spreads
# google to surface information from nhs directly in uk search results
# twitter suggests appropriate ways for brands to tweet about covid 19
# free google site audits
# google most paid links
# youtube allows creators to monetize content about coronavirus
# living with mental health challenges
# youtube replaces the trending tab with new explore tab on mobile
# negative seo lost rankings
# wordpress popup builder vulnerabilities
# attracting an audience with visual storytelling an interview with debra jasper
# google facebook twitter marketing oclock 94
# converstion time reporting facebook search ad placement marketing oclock podcast
# linkedin google targeting marketing oclock podcast
# reddit takeover trending topics marketing oclock podcast
# what makes content great
# google webmaster conferences postponed
# high converting call to action button best practices
# corporate branding
# news seo coronavirus pandemic
# covid 19 seo conferences
# what is competition analysis
# wordstream growth academy
# link outreach donts
# twitter shares tips on best tweet copy for announcing a product launch
# google coronavirus covid 19 testing website
# googles john mueller we do not use w3c validation in search results
# google confirms it is now building a nationwide coronavirus info site
# shadow dom
# automated intent classification using deep learning google sheets
# mueller says dont focus on what google thinks is quality focus on this instead
# google assistant on android can now read entire web pages out loud
# 1 in 3 business owners dont understand how google search rankings work
# google advises support for google ads gmb may be unavailable or delayed
# youtube says more videos will be removed than usual for the time being
# website builders bad seo
# wordpress 5 5 will introduce auto updates for themes and plugins
# googles john mueller martin splitt answer javascript seo questions
# page layout algorithm detail
# dont stop seo during pandemic
# google my business optimization considered the most valuable local marketing service
# google makes premium version of hangouts meet free as more people work remotely
# google seo 101 heres how to update your search results snippets
# social media content creation sins
# google experiencing glitches in search results
# amazon removes ability fba shipments non essential goods
# how to use forced bold text in google search ads
# search audiences user intent seo secret weapon
# google rolls out new types of event schema as covid 19 causes more cancellations
# facebook commits to helping small businesses during covid 19 pandemic
# seo ppc help each other
# miranda miller podcast interview
# linkedin introduces conversation ads a new message based ad format
# bing launches an interactive covid 19 tracking map
# top tips for decreasing campaign downtime
# google ads makes it easier to appeal disapproved or limited ads
# facebook puts covid 19 information on top of users news feeds
# facebook bans more types of ads in response to covid 19
# google site demotions
# webceo seo agency generate leads every day
# linkedins new ad unit this weeks digital marketing news podcast
# find snapchat influencers
# yelp launches efforts to help local businesses impacted by covid 19
# selecting anchor text advanced approach
# bing indexing api
# google launches covid 19 info site new search experience for coronavirus queries
# twitter to prioritize covid 19 tweets from verified accounts
# google discover case study
# google reasons for serps changes
# google ads introduces new policies for government documents services
# coronavirus impact search marketing
# google site search
# optimize mind joy productivity life work
# seo marketing combat coronavirus impact
# covid 19 affecting search traffic seo
# google explains how to use the search consoles index coverage report
# synonyms seo
# bing supports new schema markup for covid 19 special announcements
# google ads improves asset reporting for app campaigns with 4 new updates
# instagram launches stay home story co watching feature amid covid 19 outbreak
# google my business temporarily removes features due to covid 19
# how google manual reviews
# advance warning of penalties
# what 8 top marketers do on social media
# ethical accessibility practices for digital businesses
# yelp lets users donate to small businesses in response to covid 19 closures
# coronavirus online trends
# business through time of crisis
# understanding how google views your website chris long podcast
# safari full 3rd party cookie blocking
# seo tool free trials
# fake seo case studies on facebook
# customer experience impact on search casie gillette podcast
# hiring enterprise seo expert when how
# seo after covid 19 8 opportunities to start working on now
# youtube updates for creators improved analytics for live streams more
# coronavirus and the impact on businesses so far whos up whos down
# covid 19 working with clients
# how to work from home in quarantine
# linkedin suggests 4 types of posts to share amid covid 19 lockdowns
# google recommends ways to pause businesses in search during covid 19 pandemic
# relieving stress ideas
# pinterest launches verified merchant program with applications open to all
# better asset reporting google app campaigns marketing oclock podcast
# new google my business guidance for healthcare providers
# pinterest introduces today tab with focus on covid 19 related content
# life saving search marketing skills
# why love broad match ppc
# diagnose solving seo problems framework
# facebook focusing on live streaming as usage spikes during covid 19 lockdowns
# evolve clients content strategy ever changing algorithms
# changing landscape google serps peter leshaw podcast
# optimizing for google discover
# seomonitor marketing investments shrink
# youtube ad revenues creative output may grow during coronavirus
# google search console updates more control over data email notifications
# google blocking external resources
# google cancels april fools day plans this year due to coronavirus
# google marking a business temporarily closed doesnt impact rankings
# updated tips for optimizing content
# google martin splitt indexing infinite scroll
# google 340 million ad credits
# 5 ways to use social media for connection during times of social distancing
# how to get perfect quality scores
# google search trends and coronavirus
# chrome 81 will not load mixed content
# facebook introduces new video publishing discovery features
# microsoft ads redesign adds features
# facebook helps businesses respond to the impact of covid 19
# google to support new covid 19 special announcement schema in search results
# google is helping to make covid 19 information more accessible
# adapt marketing forced isolation
# twitter gives marketers a content calendar full of tweet prompts
# google ads pulls plug on dedicated support for many premier partners starting april 1
# google my business launches new post type for covid 19 related announcements
# close variants click fraud
# google seo 101 the evolution of search result previews
# dynamic rendering geoff atkinson podcast
# fast or slow page speed tool
# googles mueller on myth of hidden tab content
# new facebook features for video publishers marketing oclock podcast
# leaving a job you love
# strategic domain name registrations
# coronavirus pandemic impact travel industry
# brand message crisis examples
# google ads twitter amend covid policies
# google coronavirus announcement tool
# google javascript structured data guidelines
# facebook messenger launches desktop app with unlimited and free group video calls
# seo agencies stay profitable downturn
# move company seo focus
# google reveals what covid 19 special announcement schema looks like in search
# how to not work with seos
# google offers suggestions for avoiding meta description rewrites
# year of link building tips
# google may be forced to reveal its search algorithm to an seo
# clients pause marketing seo services
# google chrome delays cookie update coronavirus
# google explains how to use the removals tool in search console to hide content
# paid social messaging
# crisis marketing made simple
# facebook lets businesses show temporary service changes on their facebook pages
# pinterest adds a new shopping tab to search results
# godaddy acquires neustar
# google on web 2 0 link strategy spam
# how to adapt your existing business to go virtual podcast
# ppc program mismanagement
# pull marketing
# bing introduces new ways for site owners to control their search snippets
# ecommerce digital strategy covid 19
# youtube officially lifts monetization ban on covid 19 content
# should you discount your seo services because of coronavirus
# marketing agency tips for managing crisis
# get fast rankings with bing instant indexing api
# how to rank for questions people will ask during covid 19
# microsoft ads expands conversion inclusion options for advertisers
# facebook ads fails to reject covid 19 misinformation
# seo covid 19 retail industry impact
# finding focus peace joy coronavirus pandemic
# spotifys self serve ad studio exits beta to 18 markets worldwide
# google delays launch of new partners program to 2021
# seomonitor agency client retention
# amazon product targeting marketing oclock podcast
# googles best practices for the url structures of amp pages
# googles john mueller dont wait around for people to find your site
# the right marketing channel allows you to pivot quickly
# google links and rankings
# google answers is it ok to link to my own guest post
# google launches a series of blog posts highlighting the value of seo
# best twitter wordpress plugins
# paid media performance covid 19
# noarchive tag
# new google search features help connect people with virtual healthcare options
# covid 19 crisis recovery seo tactics
# titles meta descriptions automatically python javascript
# why ppc campaign tanking
# showing different content to google and users
# google right way to remove content
# reddit publicly disclose political ad details
# content marketing systems mindset
# alienating behaviors clients seo providers
# facebook covid 19 templates
# being different helps rankings
# google reveals how search behavior has changed during covid 19 pandemic
# become better digital marketer
# facebook redesign
# instagram stickers for businesses
# strategies for amazons new product targeting on seller central
# seo covid 19 3 areas of enterprise to focus on right now
# uplifting youtube content covid 19 pandemic
# youtubes struggle soaring views declining revenue
# google discover large images
# amazon slashes affiliate payouts
# help small businesses impacted by covid 19
# covid 19 digital recovery plan
# google ads audit
# google is launching a new video series to replace its in person conferences
# google waives ad serving fees for news publishers
# youtube video builder marketing oclock podcast
# youtube to show creators what time of day their audience in online
# share of voice
# 5 sej webinars that taught me something new
# most popular online payment solutions
# quora revamps ad manager interface
# 7 facts about pagerank
# when clients pause ppc survival tips
# google infinite scroll lazy loading
# website taxonomy
# linkedin to let users add polls to posts
# google facebook australian media
# your seo roadmap is wrong mapping digital success seo through uncertain terrain
# google on navigation menu changes and rankings
# google ads releases details around the 340m credit for smbs
# working from home top tips
# ftc fake review site crackdown
# 4 new edge seo capabilities with shopify
# 12 surprising examples of clickbait headlines that work
# better know an seo pro alan bleiweiss podcast interview
# google 301 redirects canonical
# brands looking awful during coronavirus pandemic
# reduce costs avoid staff layoffs
# consumer value reviews over credentials
# google normal site ranks for adult
# what to know about facebooks reversal of the campaign budget optimization requirement
# facebook instagram to show where popular pages are posting from
# google watchlist
# rank tracking isnt what it used to be so whats next
# google call only ads now include link option
# woman in seo
# social media global crisis
# organic google shopping listings marketing oclock podcast
# google makes it free to sell products in search results
# instagram playbook using stories in the age of covid 19
# blogging lessons
# increase ecommerce sales usability study
# dos donts ppc program
# linkedin engagement up 76 for work from home content
# instagram growth in 2020
# facebook publishes study on the mental health impact of social comparison
# how ecommerce companies can do more with less shopping ad budget in 2020
# google cuts 50 percent
# future proof brand with seo
# snap launches first commercial option on snapchat shows
# how bing ranks search results
# how bingbot works discovering crawling extracting indexing
# how bing q and a featured snippet algorithm works
# snapchat usage up during covid 19 data shows how user behavior is changing
# video ads covid 19
# artificial intelligence marketing introduction
# why make switch to virtual workforce permanent
# twitter tips most effective ways to create polls
# google search no great matches
# top podcast microphones
# google covid 19 playbook
# youtube to display fact checks in search results in the us
# microsoft ads introduces cookie based experiment feature
# how to handle plagiarism
# seo think differently about ranking mark traphagen podcast
# facebook messenger rooms drop in video chats with up to 50 people
# everything hreflang with bill hunt podcast
# seo quick wins during covid 19
# marketing in a downturn 3 steps to thrive
# seo humor googles john mueller shares bad seo advice
# google search console copy url
# google my business impressions down 59
# sitelinks search box not shown
# google facebook and microsoft release q1 earnings with similar stories
# google meet free
# shopify app marketing oclock podcast
# google on whether link value changes with age
# linkedin releases new tools for virtual job interviews
# icann blocks sale of dot org domain registry
# writing for web capitalization rules
# youtube viewership is up but youtubers are earning less money
# google seo links javascript
# how to improve content
# google suggests links in primary content hold more value
# link building metrics
# white hat vs black hat vs gray hat seo
# amazon ads skyrocketing growth in q1
# adapt ppc strategy changing times
# google search console reports on covid 19 special announcement schema
# bing pages this marketing oclock podcast
# covid 19 search trends ppc strategies
# ppc plan proceed with paid search campaigns
# godaddy hosting exploit
# google smart shopping beta testing new customer only goal
# why enterprise seo needs champion
# ecommerce site unique product descriptions
# linkedin temporarily deindexed from google
# google if choosing between desktop or mobile site choose mobile
# social media image sizes guide
# personality profiling seo agency
# youtube expands ad formats for tv screens
# 5 ecommerce seo tips to improve organic performance
# machine learning practical introduction seo professionals
# google core update marketing oclock podcast
# oncrawl r and d technical seo
# minimalist web design
# crisis communications plan
# video timestamp results google search
# extract images from documents
# google analytics wordpress plugins
# a b multivariate testing seo
# google update search console lag
# google ads beta testing curbside feature pickup in shopping
# drive paid search strategy c suite
# convert website traffic
# host location seo
# ugly urls ranking
# find freelance technical seo experts
# how to build links to pages where links are hard to build
# using google search console to find fix security issues
# seo social media mary davies interview podcast
# facebook instagram add more ways to support local businesses
# google may 2020 update analysis
# google reveals the fastest growing product categories in search results
# facebook continues creating in stream ad transparency
# linkedin pages can now host virtual live events
# 3 new must know trends for marketing
# retailer media networks
# google my business listings can link to gift card donation pages
# context marketing content campaign
# 5 brilliant ways to combine traditional digital marketing
# onboarding new seo content client
# low inventory pages ecommerce sites
# automating your seo tasks with hamlet batista podcast
# google monetization policies
# google search console security issues explained
# content monetization
# links ai google
# ecommerce seo content post covid 19
# ecommerce stores customer card
# link campaign flexibility
# john mueller negative seo rankings
# google bert rankings
# bing news pubhub digital marketing news podcast
# youtube launches 4 new features for video creators
# best video search engines
# facebook acquires giphy
# root domain subdomain ecommerce seo
# more on the google sun microsystems deal 2310
# raven tools to sponsor blueglass la 22205
# search engine roundtable best search conference coverage of 2007 6199
# seo clinic techsmith screen capture recording software 4488
# v7ns john scott on seo contests blogs branding 2953
# googles john mueller ranking isnt always the goal
# google update analysis
# ppc today letting go of what we were taught
# google lists 5 key trends shaping consumer behavior amid covid 19
# google search console adds reports for guided recipes
# seo tools arent enough for success
# google bad links traffic loss
# google on how it handles extra meta descriptions and title tags
# google antitrust
# google app dark mode
# google doesnt treat user generated content different from main content
# covid 19 digital marketing
# bing whole page algorithm
# google ads wrong right
# amazon advertising guide
# seo professional
# bad seo habits leave behind
# write users search engines
# paid search attribution
# automated ppc tips
# seo goals
# google correlation studies
# google confirms may 2020 core algorithm update rolling out today
# facebook instagram shops
# google ads shortens business identity verification time
# link penalty insights
# measure content marketing success google data studio
# 10 ways to minimize distractions still get work done
# youtubes continued land grab for tv dollars youtube select
# seo preparing for new normal
# what facebooks video ad betas tell us
# google podcast search off the record
# self sabotage
# stop wasting money content marketing
# jamie alberico podcast interview
# facebook shops for small businesses marketing oclock podcast
# twitter conversation settings
# negative keywords paid search campaigns
# google pagerank manipulation
# seo niche markets
# new google maps feature highlights wheelchair accessible places
# fake seo authority
# covid 19 digital shopping trends
# youtube video recommendations
# google may 2020 update over
# google ads incorporates retail category reporting
# google announces 3 day digital conference starting june 30
# how ecommerce businesses can do more with less shopping ad budget
# googles john mueller dont create a sitemap manually
# amazon news sports podcasting
# google guided recipes
# webceo full business recovery crisis
# facebook messenger rooms can now be created from instagram
# website accessibility meet increased demand
# github enterprise seo
# hreflang frequently asked questions
# keep creating content covid 19
# content marketing action items
# seo rebranding changing domains
# paid advertising beyond the conversion with susan wenograd podcast
# google search console core web vitals
# sleep apnea
# google page experience ranking factor marketing oclock podcast
# googles top stories to show more than just amp pages
# twitter schedule tweets
# google adds an anxiety disorder self assessment to search results
# executive order weaken cda 230
# clickcease how much ppc fraud costing your business
# seomonitor post pandemic seo agencies
# google rolls out 3 new attributes for gmb listings
# link profile analysis basics
# google now has 6 ways to measure core web vitals
# ads appearing on googles network alongside covid 19 misinformation
# facebook lets users delete old posts in bulk
# google tests showing web pages in youtube search results
# linkedin adds engagement remarketing for video and lead ads
# bing backlink research tool
# google is currently experience indexing problems
# effective strategist
# youtube rolls out new features to help creators boost merch sales
# google explains author page importance
# diagnose google ads performance changes faster with explanations
# snapchat rolling out dynamic ads globally
# top seo writing tools
# were pausing work coping with covid 19 client anxiety
# co citation co occurrence how important are they for seo today
# google my business update add more hours for specific services
# unnatural guest post links
# linkedin engagement retargeting marketing oclock podcast
# duckduckgo questioned by authorities over google antitrust investigation
# octoboard win seo ppc save money doing it
# google updates featured snippets
# google explains content pruning
# bing webmaster tools visual guide new updated features
# content marketing what why where who when how
# bing site scan tool audits sites for technical seo issues
# links ranking google
# python monitor measure website performance
# are you charging enough a quick guide to digital marketing prices
# why you should be using google discovery campaigns
# improve click through rate
# googlebot paginated pages
# productivity tips content marketing
# facebook tests email marketing tools for business pages
# pinterest shows shoppable pins in visual search results
# google finds over 25 billion spammy pages every day
# facebook messenger can now be used to answer customer messages
# instagram says sites may need permission to embed photos
# change user agent
# scaling back ppc program
# youtube customize channel
# twitter sharing prompt
# change browser default search engine
# facebook relaxes ban on ads for non medical masks
# facebook search results now include wikipedia knowledge panels
# avoid bad press
# link building obtain track backlinks
# google banning certain categories for employment housing and credit ads
# supermetrics marketing data warehouse
# what is the best word count for seo
# search trend data cross over content ideation
# prabhakar raghavan
# snapchat mini apps marketing oclock podcast
# natural language generation changes seo
# leadership vacuum search engine marketing
# social media get results without million dollar budget
# google chrome to hide parts of urls in future update
# make youtube video builder tool more useful
# start using social commerce
# google guest posting for links warning
# google rankings for new sites could fluctuate for up to a year
# google search console adds new data for recipe structured data
# snapchat launches ads certification program
# google advises against using nofollow links when migrating sites
# instagram pinterest roll out new features for pride month
# users now able to block political ads on facebook and instagram
# google ads policy crackdowns continue
# google my business content seo
# twitter voice tweets
# google ads isnt working
# attribute content value
# create engaging content
# instagram to surpass twitter as a popular news source
# google ads simple tips make more money
# google on how to use the manual action report in search console
# product pages seo content backlinks
# local seo value
# google explains why field data is more reliable than lab data
# googles new chrome extension supports scroll to text fragment feature
# voice tweets marketing oclock podcast
# letusrespond boost business google reviews covid 19
# amazon brand analytics
# analytics guide seo beginners
# facebook outage
# wordpress plugins blogs businesses
# link building research tips 10x links
# twitter tricks tips
# remote working challenges
# google mobile first index tips
# google is offering businesses free promotion in google maps
# google adds fact check label to image search results
# facebook goes after companies for fake likes comments
# instagram pr work from home
# spend google ad credits
# google pulls ads from two conservative websites
# googles internal anchor text
# after on page seo whats next
# mobile first indexing and ranking
# enterprise seo team communication
# schema success stories structured data boost traffic
# seo monitor seo agency kpis dashboard
# google to see unprecedented drop in ad revenue
# 5 ways to evaluate your authors for seo
# utm codes
# red flags interview
# comprehensive content audit
# seo seasonality overcoming dips during slow season
# hackers exploiting google analytics
# data these 8 industries are ruling the ppc market during covid 19
# keen
# bing image based product search
# new instagram advertisers no longer need a facebook page
# microsoft digital marketing center marketing oclock podcast
# google expands business messaging to mobile websites
# facebook update likely to hurt traffic to older web pages
# octoboard ppc reporting strategies for 2020
# sentiment analysis
# ranked entities google search results
# page feeds dynamic search ads
# marketing technology data racist biased fix
# google explains how youtube search works
# linkedin content creation is up 60 compared to last year
# facebook ad ban heats up heading into july stock drops 8
# correction apple safari will not block google analytics tracking
# top 10 tools for bulletproof seo content strategies
# battle brand squatting ppc
# google shopping ads are free to display in main search results
# interpret ppc data correctly
# does google use sentiment analysis to rank web pages
# google combining search console analytics data into one report
# facebook algorithm now prioritizes original reporting
# client connection tips
# should i bid on branded terms in sem
# ppc campaigns filter less qualified audiences
# google analytics filters bot traffic from app web properties
# bing ranking factors revealed in update to webmaster guidelines
# conversion analysis
# 5 practical tips to step up your audience targeting game
# google ambient computing
# yelp facts
# convert organic traffic leads
# digital pr define good drive measurable gains
# inbound links beginners guide
# google polls seos and finds workload is up during covid 19
# facebook algorithm favor original reporting marketing oclock podcast
# googlebot adding products shopping carts
# ccpa roll out causes havoc for facebook advertisers
# seomonitor agency client communication new normal
# searching clicking site increase rankings
# google thumbnail images in serps
# facebook targeting options
# google a small fraction of spam reports result in manual actions
# linkedin to prevent users from spamming page follow invites
# india proposes access to google and amazon algorithms
# in a year of worsts seo just became the best
# find improve underperforming content guide
# wordpress bans links to commercial blogs
# instagram shopping tab
# google rich results structured data test tool
# wordpress seo beyond basics
# instagram to let users pin comments to the top of posts
# alex valencia podcast interview
# updating content news seo time on site more with loren baker podcast
# seo search marketing heavy metal music
# 1 line layouts
# google search console hidden gems
# travel business opportunities
# if i were starting a small travel business this would be my marketing plan
# what it takes to run a podcast with marketing oclock podcast
# google rich results test out of beta marketing oclock podcast
# linkedin adds name pronunciation audio clips to user profiles
# facebook live best practices
# linkedin company page set up optimize
# a b testing
# pinterest facts
# unrealistic seo expectations
# wp rocket issue blocked structured data to google
# youtube continues testing immersive product experiences
# signs digital marketing strategy needs overhaul
# google ads to ban spying products software
# google image search traffic
# seo machine learning joining forces
# facebook facts
# generate structured data automatically computer vision
# automatic reload script seo
# which ppc metrics should you focus on
# pinterest algorithm
# google analytics adds predictive features for advertisers
# youtube updating algorithm again
# google recipe structured data update
# most influential women twitter
# seos work with sales team drive business growth
# chrome 84 3rd party cookies
# google adds new features to responsive search ads
# google discover ranking
# use heatmaps seo strategy
# writing google core algorithm user intent seo
# grow by mediavine wordpress plugin
# combine seo ppc data
# google first page clicks
# google search allegedly boosts youtube results ahead of competitors
# content marketing lean times tips
# googles john mueller search is not a science
# hulu launches beta for self serve advertising platform
# how would an seo agency be built today consumers trends
# how not to work with ppc managers
# facebook coronavirus emojis
# 2019 top youtube searches and channels so far
# seo tips
# google privacy lawsuit android apps
# google adds increased visual options for shoppers and brands
# links noindex pages seo
# google updates employer aggregate rating structured data
# top youtube searches
# google search site command is broken
# creative ways to use google image search
# google image search 2
# how bing image video algorithm works
# website accessibility compliance
# google search console news search type
# great seo without coding
# content pruning seo
# twitter hack compromises verified accounts marketing oclock podcast
# q3 ad revenue results snap and the facebook anticipation
# google seo 101 website crawl budget explained
# noindex category archive pages
# instagram business fundraiser
# link remediation link removals disavows
# blocking special files in robots txt
# does google have a problem ranking original publishers
# google discover large images 2
# google delays mobile first index
# enterprise seo job requirements
# google mortgage information search
# facebook enables 50 person live streams with messenger rooms
# affiliate marketing blogs
# google advises redesign impact on seo
# generate data driven copy ecommerce category pages gpt 2
# how would an seo agency be built today current business models
# hulu launches ad manager beta marketing oclock podcast
# google domain diversity in serps
# googles john mueller discusses changes to search
# google shakes up e commerce with commission free sales
# facebook most liked posts are not the most viewed
# pinterest search trends
# amazon brand registry guide
# bing url submissions wordpress plugin
# mobile app daily usage
# digiday reveals 56 of advertisers paused facebook spend in july
# meow attack
# javascript 101 seo
# youtube revenue rpm
# most influential women instagram
# google web story validation tool
# how to improve your websites e a t
# google intrusive interstitials
# ppc campaign engagement triggers
# bing url submissions wordpress plugin experiencing issues
# google ceo testimony
# digital marketing realities virtual augmented
# google advises site owners of rise in work from home searches
# 11 simple facebook ad tips to drive more conversions
# 15 ways to optimize a paid search campaign
# new bing webmaster tools review
# google updates search console with more structured data support
# google on using quora for links
# google highlights black owned businesses in search results
# linkedins sharing api is broken not fetching images
# remembering our friend honoring what he started
# does google use analytics for ranking purposes
# seomonitor better agency client communication
# important tags seo
# google seo 101 page speed optimization
# quora launches lead generation forms for advertisers marketing oclock podcast
# extra structured data could be useful
# google doubles up on articles in the top stories carousel
# chrome 85 tagged pdf
# twitter is considering these premium features in a subscription model
# automated high quality content generation
# google maps goes social giving each user their own profile
# google link juice
# google be careful relying on 3rd parties to render website content
# how set up seo agency
# google analytics privacy settings
# 41 of googles first page contains links to google products
# google adds new structured data jobbenefits industry
# privacy personalization ppc
# instagram reels launches worldwide to compete with tiktok
# google ads rolling out multiple updates to app campaigns
# is groupon marketing worth it for businesses
# googles search quality raters do not directly influence rankings
# pagerank predict nhl playoffs
# amp seo everything you need to know
# facebook messenger plugin for websites receives major update
# build scale program global seo success
# google advanced image search guide
# content distribution getting started
# google explains negative reviews rankings
# google ads advertisers can now capture leads from youtube
# google seo 101 mobile first indexing problems
# google martin splitt meta description
# google holding first ever virtual conference on august 26th
# googles rich results test tool supports article markup
# buy redirect expired domains
# top youtube searches during covid 19 pandemic
# google ads tools
# google search preference menu
# wordpress 5 5 xml sitemap news
# structured data relevance reading between google guidelines
# google shows images of black doctors in search for white doctors
# facebook closing an election ad loophole
# core web vitals benchmarks
# google ads bumper ads
# align seo ppc ecommerce tips
# understanding the modern serp
# facebook warning users before sharing covid 19 links
# linkedin sells slideshare to scribd
# hard soft skills marketers need
# shopify web vitals app
# link building roi 2
# google travel portal covid 19
# instagram introduces tiktok rival reels marketing oclock podcast
# executive order gives tiktok 45 days
# tiktok starts 200 million fund to pay users for content
# instagram to launch a tiktok competitor in the us next month
# tiktok launches self serve advertising platform globally
# tiktok debuts tiktok for business signals larger move for ad dollars
# tiktok finally opens ads api to a partner sprinklr
# tiktok begins letting some users add website links in profiles
# tiktok is projected to surpass 50 million us users by 2021
# heres how much brands are paying for sponsored content on tiktok youtube
# tiktok is working on a way for advertisers to target users in other apps
# tiktoks parent company bytedance is launching a search engine
# tiktok was downloaded more times than instagram last year
# twitter allows users to limit replies marketing oclock podcast
# why businesses need to be on tiktok
# how google improves search results
# google seo 101 all about canonicalization
# ineffective seo habits
# google search worldwide glitch
# technical seo audit role
# how wordpress 5 5 plugin protection
# questions to ask potential seo clients
# natural language processing python seo
# ...
# youtube launches new analytics custom shorts thumbnails
# twitters revenue down 40 as 500 top advertisers pull out
# google removes embedded podcasts from search results
# examples contact us pages
# newsjacking examples
# linkedin fastest growing jobs
# automattic announces blaze ad network of millions of wordpress com tumblr sites
# interactive content types engage your audience
# openai gpt 4
# video marketing an in depth guide for every business owner
# googles founders return how chatgpt is changing search
# chatgpt pro early access users share their thoughts
# google ads down for advertisers google confirms
# tiktok staff can decide what goes viral
# social media posts real estate inspiration
# yoast seo 20
# youtube seo video optimization
# microsoft openai extend deal to make ai accessible to everyone
# how to avoid plagiarism
# linkedins new feature can help you find must read newsletters
# mobile seo optimize devices webceo spcs
# google merchant listing experiences tips for optimizing product pages
# states vs google a closer look at the dojs antitrust lawsuit
# microsoft ceo every app is going to be an ai app
# twitter rolls out search keywords ads to all advertisers
# wayback machine 5 alternatives to try
# facebook marketing beginners guide
# google optimize discontinued what businesses need to know
# linkedin data what businesses advertisers need to know
# google discover follow feed guideline update
# meta reinstates trump to facebook instagram
# sustaining saas brand organic channel recession
# where are the advertisers leaving twitter super bowl
# 7 content marketing best practices in 2023
# is chatgpt use of web content fair
# want entrepreneur 72375
# most emotionally engaging christmas ads
# twitter amazon link add items shopping cart single tweet
# john lewis 2019 christmas advert
# is a super bowl ad the equivalent of lighting money on fire
# coke and oreo battle of the legacy brands 57969
# coronavirus response videos brands
# super bowl ads marketing takeaways
# will facebook instant articles affect seo
# interview andrew pincock trafficado pubcon 74887
# seo target multiple cities
# wordpress admin ui is bad
# press materials
# mobile seo
# wordpress seo
# seo tools
# content marketing kpis
# ppc guide
# ecommerce guide
# technical seo
# holiday marketing
# seo audit
# content marketing
# enterprise seo
# facebook ads
# google eat
# social media ebook
# core web vitals
# saas content marketing
# law firm seo
# social media
# link building guide
# keyword research ebook
# content optimization
# retargeting guide
# content marketing finance
# search engines
# contact 3
# contact
# real estate content guide
# content marketing law firms
# newsletter sign up
# ask an seo advice column
# google algorithm history
# keyword research
# enterprise seo guide
# local seo
# privacy policy
# state of seo agency
# state of seo in house
# state of seo
# ranking factors
# writers guidelines for search engine journal
# banners
# advertise get in touch
# advertise
# ppc trends
# seo tools agency
# link building dark side
# ux seo
# seo strategy
# on page seo
# seo
# about
# seo trends
# webinar lp seo in 2024 top priorities challenges and opportunities
# webinar lp how an enterprise digital pr firm earns 100s of links in 30 days
# webinar lp how we built a strong 10 million agency a proven framework
# webinar lp 10 successful ways to improve your serp rankings with ahrefs
# b2b lead generation
# webinar lp 2024 google serp features new strategies to gain visibility
# careers
# ebooks
# google algorithm history rankbrain
# google algorithm history panda update
# google algorithm history fred update
# google algorithm history emd update
# google algorithm history hummingbird update
# google algorithm history penguin update
# google algorithm history freshness algorithm
# google algorithm history florida update
# content marketing kpis business conversion
# content marketing kpis metrics
# seo tools link building tools
# seo tools technical seo
# seo tools keyword research tools
# seo tools competitive analysis
# seo tools rank tracking tools
# seo tools reporting
# seo tools seo software suites
# seo tools browser extensions plugins
# seo tools project management
# seo tools excel
# link building guide natural link
# link building guide link building terminology
# link building guide myths link building
# link building guide link earning
# link building guide scalability
# link building guide sustainable
# link building guide bing vs google
# link building guide link building techniques good bad ugly
# link building guide types of links how to build them
# link building guide measure link quality
# link building guide link building fundamentals
# link building guide technical seo
# link building guide affiliate
# link building guide broken link building
# link building guide competitors links
# link building guide controversy
# link building guide content marketing techniques
# link building guide data driven content
# link building guide ego bait content
# link building guide local charities events
# link building guide guest blogging
# link building guide helping others
# link building guide images visual content
# link building guide interactive content
# link building guide gratitude
# link building guide reclaim lost broken links
# link building guide link worthy content
# link building guide local citation building
# link building guide do something newsworthy
# link building guide outreach
# link building guide podcasts
# link building guide pr process
# link building guide question and answer sites
# link building guide radio stations
# link building guide relationship building
# link building guide thought leadership speaking
# link building guide taking a stand
# link building guide how to build links using testimonials reviews
# link building guide free tools
# link building guide trending topics
# link building guide unlinked brand mentions
# link building guide video youtube
# link building guide popular tactics to avoid
# link building guide bad links risky tactics
# link building guide checklist
# link building guide internal
# link building guide social profiles
# link building guide resource links pages
# link building guide link building tactics avoid
# link building guide reciprocal links
# link building guide online directories
# seo what people search for
# seo best seo resources
# seo seo statistics
# seo introduction to mobile seo
# seo how people search
# seo seo myths
# seo why keywords important seo
# seo why keyword research
# seo seo success factors
# seo top seo kpis
# seo seo history
# seo content important seo
# seo search authority
# seo seo strategy
# seo why links important seo
# seo how to become an seo expert
# seo agile seo moving from strategy to action
# seo how long seo takes
# seo why is search important
# seo know your audience
# seo what to do when things go wrong
# seo brand building strategy
# seo track google algorithm updates
# seo webmaster guidelines
# seo why do people visit websites today
# seo strategy vs tactics
# seo how seo works
# seo types of webpages
# seo seo strategy trade offs
# seo see think do care seo strategy
# seo machine learning
# seo seo experts
# seo where seo and user experience ux collide
# seo meet search engines
# seo seo conferences
# local seo analyzing search competition
# local seo what is local seo why local search is important
# local seo listings management local seo tools
# local seo getting started
# local seo large enterprises
# local seo local search ranking signals
# local seo local link building
# local seo local business reviews
# local seo why nap user experience are crucial to local seo
# local seo optimize google my business
# local seo local content examples
# ppc guide what is ppc paid search
# ppc guide best ppc ad networks
# ppc guide quality score
# ppc guide keywords
# ppc guide click through rate ctr
# ppc guide ad targeting options
# ppc guide ad groups
# ppc guide ad extensions
# ppc guide a complete guide to ppc ad formats
# ppc guide shopping ads
# ppc guide top ppc experts
# ppc guide most important ppc kpis
# ppc guide text ad copywriting best practices
# ppc guide how to develop ppc strategy
# ppc guide ppc advertising benefits
# on page seo seo writing
# on page seo eat ymyl
# on page seo essential factors
# on page seo keyword cannibalization
# on page seo title tag optimization
# on page seo header tags
# on page seo image optimization
# on page seo internal external links ctr
# on page seo content audit checklist
# on page seo optimize meta description
# on page seo headline writing tips
# ecommerce guide must have website features
# ecommerce guide effective link building strategies
# ecommerce guide on page seo
# ecommerce guide advanced ppc strategies
# ecommerce guide content strategy
# ecommerce guide site navigation
# ecommerce guide google images
# ecommerce guide technical seo
# ecommerce guide perform keyword research
# ecommerce guide social media marketing strategies
# holiday marketing holiday seo
# holiday marketing holiday marketing calendar template
# technical seo javascript fundamentals cheat sheet
# technical seo schema
# technical seo http https why secure site
# technical seo meta robots tags robots txt
# technical seo duplicate content issues
# technical seo url structure
# technical seo web hosting
# technical seo 404 vs soft 404 errors
# technical seo redirects
# technical seo website navigation
# social media increase engagement facebook business page
# social media optimize twitter profile
# social media linkedin for businesses
# social media pinterest for business
# social media linkedin personal brand
# social media reddit guide
# social media instagram for business
# social media emerging channels trends
# social media snapchat for business
# social media facebook messenger marketing chatbots
# social media completely optimize facebook page
# social media top tools
# social media get instagram followers
# social media tweet ideas for businesses
# social media linkedin advertising guide
# social media who has the most subscribers on youtube
# social media social listening
# social media social media platforms
# search engines algorithms
# search engines machine learning
# search engines user behavior
# search engines universal search
# search engines display search results
# search engines ranking
# search engines answering questions
# search engines rendering
# search engines website indexing
# content marketing brand style guide
# content marketing evolution
# content marketing goals
# content marketing case studies
# content marketing how to integrate content marketing seo
# content marketing editorial calendar
# content marketing places to share
# content marketing content marketing matters
# content marketing top tools create better content
# content marketing content types
# content marketing tools
# seo audit page level factors
# seo audit duplicate content
# seo audit content length
# seo audit website updates
# seo audit seo audit checklist link profile audit
# seo audit on site technical seo factors
# seo audit technical
# seo audit website content factors
# seo audit domain factors
# seo audit chrome devtools to diagnose site issues
# seo audit advanced seo audit techniques excel
# seo audit seo audit tools
# law firm seo why seo matters for law firms
# law firm seo what is law firm seo
# law firm seo seo friendly law firm website
# law firm seo how to attract law firm backlinks
# law firm seo generate positive client reviews
# law firm seo seo blogging strategy
# law firm seo local seo law firms more clients
# core web vitals how to measure
# core web vitals google faq provides insights
# core web vitals cumulative layout shift
# core web vitals largest contentful paint
# core web vitals first input delay
# core web vitals google lighthouse
# enterprise seo link building best practices
# enterprise seo brand equity link building
# enterprise seo the top 4 enterprise seo platform tools an in depth review
# enterprise seo choosing right agency
# enterprise seo visual voice vertical
# enterprise seo what is enterprise seo
# enterprise seo top challenges
# enterprise seo pillars of success
# enterprise seo how to plan your 2021 enterprise seo strategy
# enterprise seo strategies tactics that work
# google eat what is it
# google eat quality raters guidelines
# google eat structured data
# google eat surprising facts about e a t seo
# google eat biggest misconceptions
# google eat eat link building
# facebook ads how do facebook ads work
# facebook ads how to set budget
# facebook ads creative tips
# facebook ads remarketing strategies
# facebook ads features
# facebook ads objective
# facebook ads improve conversion
# facebook ads targeting options
# wordpress seo how to build wordpress site
# wordpress seo improve wordpress site seo
# wordpress seo best wordpress seo plugins
# wordpress seo wordpress site launch checklist
# wordpress seo protect from hackers
# wordpress seo mistakes to avoid
# wordpress seo common duplicate content issues
# wordpress seo local seo best practices
# wordpress seo wordpress seo without plugin
# wordpress seo harden security
# wordpress seo how to choose wordpress plugins
# keyword research how to get started
# keyword research higher local rank
# keyword research mistakes to avoid
# keyword research tools techniques
# keyword research long tail keywords
# keyword research localization success
# keyword research social media
# keyword research free tools
# keyword research free keyword research tool
# ranking factors 404 errors google
# ranking factors chrome bookmarks
# ranking factors click depth
# ranking factors cocitation
# ranking factors content length
# ranking factors domain age
# ranking factors dwell time
# ranking factors google ads
# ranking factors html heading tags h2 h6
# ranking factors html lists
# ranking factors outbound links
# ranking factors local citations
# ranking factors google adsense
# ranking factors contextual links
# ranking factors anchor text
# ranking factors click through rate
# ranking factors contact information ranking
# ranking factors content
# ranking factors direct traffic
# ranking factors using disavow tool
# ranking factors latent semantic indexing
# ranking factors inbound links
# ranking factors manual actions
# ranking factors paid links
# ranking factors h1 tags onpage
# ranking factors image quantity
# ranking factors meta descriptions
# ranking factors physical proximity to searcher
# ranking factors tf idf
# ranking factors review sentiment
# ranking factors subdomain subdirectory
# ranking factors reconsideration requests
# ranking factors user search history
# ranking factors schema markup ranking
# ranking factors whois information
# ranking factors xml sitemaps
# ranking factors www vs non www
# ranking factors tabbed content
# ranking factors user generated content
# ranking factors link velocity
# ranking factors title tags
# ranking factors 301 redirects
# ranking factors text formatting ranking factor
# ranking factors website quality score
# ranking factors gov links
# ranking factors spelling grammar ranking factors
# ranking factors amp google
# ranking factors first link priority
# ranking factors edu links
# ranking factors search quality rater guidelines
# ranking factors social signals rankinng factor
# ranking factors author authority
# ranking factors nofollow links
# ranking factors google mum
# ranking factors keyword stuffing
# ranking factors keyword prominence
# ranking factors domain authority
# ranking factors google search console
# ranking factors domain name
# ranking factors rankbrain
# ranking factors reading level
# ranking factors internal links guide
# ranking factors ip address
# ranking factors fresh content
# ranking factors crawl errors budget
# ranking factors code to text ratio
# ranking factors breadcrumb navigation
# ranking factors bounce rate
# ranking factors relevance distance prominence
# ranking factors mobile friendliness
# ranking factors language
# ranking factors meta keywords
# ranking factors https
# ranking factors canonicalization
# ranking factors e e a t
# ranking factors keyword stemming
# ranking factors urls
# ranking factors sitewide links
# ranking factors link stability
# ranking factors keyword density
# ranking factors page speed
# ranking factors bbb rating
# ranking factors deep link ratio
# ranking factors domain history
# ranking factors top ranking factors
# ranking factors alt text
# ranking factors core web vitals
# ranking factors google analytics
# ranking factors syndicated content
# ranking factors last years google ranking factors changes explained
# seo trends seo experts on helpful content its bigger than you think
# seo trends prepare for search generative experience

# %% [markdown]
# ## Introducing Spacy
#
# https://spacy.io/usage/spacy-101
#
# https://spacy.io/usage/examples
#
# https://spacy.io/api/annotation

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: setuptools in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: numpy>=1.19.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (22.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)

# %%
import spacy
from spacy import displacy

# %%
# !python -m spacy download en
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (22.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: setuptools in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.6.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.64.1)
# Requirement already satisfied: jinja2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: numpy>=1.19.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.12)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.11.17)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ntohsi/anaconda3/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  how to seo podcast site<br>track offline conversions
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  advertising<br>do ugly sites sell<br>youtubes coppa changes begin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  possibly affecting creator revenue<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     googles john
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  mueller our seos have it harder than others<br>seo struggles<br>challenge
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ads trademark disputes<br>best amp wordpress plugins<br>chrome push notification blocker<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  assistant now has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users worldwide<br>track organic conversions<br>seo reports which metrics matter how to use them well<br>google optimization score ppc<br>twitter rolls out a new ad unit in the explore tab<br>b2b paid advertising
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     greg finn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  podcast<br>instagram user growth drops to lower levels than previously expected<br>female marketers<br>facebook pages to redesign good for the advertiser
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8875
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>quality raters guidelines ranking signals<br>stepping into the unknown<br>facebook is preparing to launch a desktop redesign to all users<br>duckduckgo is now a default search engine option on android in the eu<br>actionable tasking seo answer important questions<br>biggest link building misconceptions<br>googles hogging
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  your traffic how to get it back<br>inspiring instagram contests<br>waze local paid marketing<br>google ads introduces bid simulator support for smart bidding<br>are modal popups searchable<br>introduction to python seo spreadsheets<br>seo platform wishlist<br>user behavior tracking tools<br>google
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     january 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  core update is rolling out imminently<br>google ads makes parallel tracking mandatory for video campaigns<br>pinterest overtakes snapchat in popularity among us users<br>youtube organic visibility
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google serps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>first party data ppc<br>seos are in high demand according to linkedins data<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  introduces a new shopping section in search results<br>tony wright better know an seo podcast<br>linkedin brings
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new features to linkedin pages<br>snapchat facts<br>tips get pinterest followers<br>google structured data has no impact on ranking in web search<br>youtube shows users comment history in new profile cards<br>new baby seo agency same time<br>google changes the look of paid and organic search results on desktop<br>instagram drops igtv button due to lack of use<br>publish content com co uk websites<br>a new search engine enters the market onesearch from verizon media<br>machine learning spam in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
# google desktop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  search results marketing oclock podcast<br>brand identity<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     googles john
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  mueller on optimizing images for search results<br>marketing website accessibility assumptions<br>how to evaluate link opportunities<br>google data vocabulary structured data<br>growing organic traffic by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50k
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius:

# %% [markdown]
# ## Building a Knowledge Graph
#
# 1. https://www.analyticsvidhya.com/blog/2019/10/how-to-build-knowledge-graph-text-using-spacy/
#
# 2. https://www.analyticsvidhya.com/blog/2019/09/introduction-information-extraction-python-spacy/?utm_source=blog&utm_medium=how-to-build-knowledge-graph-text-using-spacy
# 3. https://www.kaggle.com/shivamb/spacy-text-meta-features-knowledge-graphs

# %% [markdown]
# Let’s get the dependency tags

# %%
for tok in doc[:100]:
  print(tok.text, "...", tok.dep_)
# Out:
# google ... nsubj
# how ... advmod
# to ... aux
# seo ... nsubj
# podcast ... compound
# site ... compound
#
#  ... dep
# track ... compound
# offline ... amod
# conversions ... dobj
# microsoft ... compound
# advertising ... dobj
#
#  ... dep
# do ... aux
# ugly ... amod
# sites ... nsubj
# sell ... ccomp
#
#  ... dep
# youtubes ... compound
# coppa ... compound
# changes ... dobj
# begin ... conj
# today ... npadvmod
# possibly ... advmod
# affecting ... advcl
# creator ... compound
# revenue ... compound
#
#  ... dep
# googles ... dobj
# john ... compound
# mueller ... dobj
# our ... poss
# seos ... nsubj
# have ... ccomp
# it ... nsubj
# harder ... ccomp
# than ... mark
# others ... compound
#
#  ... dep
# seo ... nsubj
# struggles ... poss
#
#  ... dep
# challenge ... compound
# google ... compound
# ads ... compound
# trademark ... compound
# disputes ... dobj
#
#  ... dep
# best ... amod
# amp ... nmod
# wordpress ... amod
# plugins ... compound
#
#  ... dep
# chrome ... compound
# push ... compound
# notification ... compound
# blocker ... compound
#
#  ... dep
# google ... compound
# assistant ... nsubj
# now ... advmod
# has ... advcl
# 500 ... compound
# million ... nummod
# users ... dobj
# worldwide ... advmod
#
#  ... dep
# track ... advcl
# organic ... amod
# conversions ... compound
#
#  ... dep
# seo ... compound
# reports ... dobj
# which ... nsubj
# metrics ... nsubj
# matter ... relcl
# how ... advmod
# to ... aux
# use ... xcomp
# them ... dobj
# well ... advmod
#
#  ... dep
# google ... compound
# optimization ... compound
# score ... compound
# ppc ... compound
#
#  ... dep
# twitter ... dobj
# rolls ... conj
# out ... prt
# a ... det
# new ... amod
# ad ... compound
# unit ... dobj
# in ... prep
# the ... det
# explore ... compound
# tab ... pobj
#
#  ... dep
# b2b ... pobj

# %% [markdown]
# The rule can be something like this — extract the subject/object along with its modifiers, compound words and also extract the punctuation marks between them.

# %%
from spacy.matcher import Matcher 
from spacy.tokens import Span 
import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# To build a knowledge graph, the most important things are the nodes and the edges between them.
#
# The main idea is to go through a sentence and extract the subject and the object as and when they are encountered

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %%
for t in [x for x in new_df["headline"].tolist() if len(x) > 0][:100]:
  print(get_entities(t))
# Out:
# ['', 'how podcast site']
# ['', '']
# ['ugly  sites', '']
# ['youtubes coppa changes', 'possibly creator revenue']
# ['googles john seos', 'harder  others']
# ['seo', '']
# ['', '']
# ['', '']
# ['', 'notification blocker']
# ['google assistant', '500 million 500 users']
# ['', 'organic  conversions']
# ['seo metrics', 'how  them']
# ['', '']
# ['twitter', 'new explore tab']
# ['b2b', 'advertising greg']
# ['instagram user growth', 'lower  levels']
# ['', '']
# ['', 'facebook advertiser']
# ['', 'ranking quality raters signals']
# ['', 'unknown']
# ['facebook', 'desktop users']
# ['duckduckgo', 'now search engine eu']
# ['tasking  seo', 'important  questions']
# ['', '']
# ['', 'how  it']
# ['', '']
# ['', '']
# ['google ads', 'smart simulator bidding']
# ['', '']
# ['', 'python seo spreadsheets']
# ['', '']
# ['', '']
# ['2020 core update', '']
# ['parallel  tracking', 'video campaigns']
# ['pinterest', 'users']
# ['', 'organic google serps']
# ['', '']
# ['seos', 'high linkedins data']
# ['google', 'new search results']
# ['tony  wright', 'better seo podcast']
# ['linkedin', 'linkedin  pages']
# ['snapchat', '']
# ['tips', 'pinterest  followers']
# ['google structured google data', 'web search']
# ['users', 'new profile cards']
# ['', '']
# ['google', 'paid search desktop']
# ['instagram', 'igtv use']
# ['', '']
# ['new search engine', 'verizon market media']
# ['', 'machine learning google']
# ['', 'oclock podcast']
# ['', '']
# ['', 'search results']
# ['', '']
# ['', 'how link opportunities']
# ['', '']
# ['', 'monthly visitors case study']
# ['wordpress  schema', '']
# ['googles john mueller', 'redirect  chain']
# ['one  violation', 'manual  action']
# ['ryan jones', 'better seo podcast']
# ['', 'yelp seo rank']
# ['', '']
# ['new dataset search engine', 'beta']
# ['', '']
# ['twitter users', 'direct  emojis']
# ['it', 'similar search history']
# ['chrome', 'technical seo audits']
# ['', 'featured oclock podcast']
# ['', '']
# ['featured  snippets', '']
# ['', 'holidays strategy']
# ['duckduckgo', 'quick search results']
# ['google web pages', 'organic  listings']
# ['google', 'desktop search changes']
# ['', 'looping video app ios']
# ['libraries', 'building']
# ['', 'technical seo budget']
# ['', '']
# ['', 'content marketing 2020']
# ['googles', 'organic traffic study']
# ['it', 'temporarily search results']
# ['bing', 'missed  clicks']
# ['google', 'new beginners video']
# ['', 'quality search']
# ['', 'success ppc campaigns']
# ['google ads', 'standard  may']
# ['', 'business']
# ['', '']
# ['', 'skyscraper content']
# ['updates responsive search ads', 'reports']
# ['marketing analytics tool', 'privacy concerns']
# ['', 'non tips']
# ['', 'pressure']
# ['', '']
# ['', 'launches sos coronavirus']
# ['', '']
# ['', 'traffic']
# ['', '']

# %%
entity_pairs = []

for i in tqdm([x for x in new_df["headline"].tolist() if len(x) > 0]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████████████████████████████████| 7173/7173 [00:15<00:00, 474.08it/s]

# %%
entity_pairs[10:20]
# Out:
# [['', 'organic  conversions'],
#  ['seo metrics', 'how  them'],
#  ['', ''],
#  ['twitter', 'new explore tab'],
#  ['b2b', 'advertising greg'],
#  ['instagram user growth', 'lower  levels'],
#  ['', ''],
#  ['', 'facebook advertiser'],
#  ['', 'ranking quality raters signals'],
#  ['', 'unknown']]

# %% [markdown]
# Our hypothesis is that the predicate is actually the main verb in a sentence.

# %%
def get_relation(sent):
    doc = nlp(sent)

  # Matcher class object 
    matcher = Matcher(nlp.vocab)

  #define the pattern 
    pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

    matcher.add("matching_1", patterns=[pattern]) 

    matches = matcher(doc)
    k = len(matches) - 1

    span = doc[matches[k][1]:matches[k][2]] 

    return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm([x for x in new_df["headline"].tolist() if len(x) > 0])]
# Out:
#  25%|█████████▋                            | 1828/7173 [00:04<00:11, 458.69it/s]

# %%
entity_pairs[10:20]

# %%
relations[10:20]

# %%
pd.Series(relations).value_counts()[4:50]

# %%
pip install --upgrade matplotlib networkx

# %% [markdown]
# Let's build the knowledge graph

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Assuming G is your graph object
fig, ax = plt.subplots(figsize=(12, 12))

# Calculate node positions
pos = nx.spring_layout(G)

# Draw the graph with specified node positions, and edge colormap
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos=pos, ax=ax)

plt.show()

# %% [markdown]
# use only a few important relations to visualize a graph. I will take one relation at a time.

# %%
# def display_graph(relation):

#   G=nx.from_pandas_edgelist(kg_df[kg_df['edge']==relation], "source", "target", 
#                             edge_attr=True, create_using=nx.MultiDiGraph())

#   plt.figure(figsize=(12,12))
#   pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
#   nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
#   plt.show()

# %%
def display_graph(relation):
    G = nx.from_pandas_edgelist(kg_df[kg_df['edge'] == relation], "source", "target", 
                                edge_attr=True, create_using=nx.MultiDiGraph())
    
    fig, ax = plt.subplots(figsize=(12, 12))  # Create a new figure and axis
    pos = nx.spring_layout(G, k=0.5)  # k regulates the distance between nodes
    
    # Draw the graph with specified node positions, and edge colormap
    nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos=pos, ax=ax)
    
    plt.show()

# %% [markdown]
# Now, when I run ```display_graph("launches")```, I get the graph at the begining of the article.

# %%
display_graph("launches")

# %%
display_graph("introduces new")

# %%
display_graph("reveals")

# %%
display_graph("explains")

# %%
display_graph("improve")

# %%
display_graph("expands")

# %%
pd.Series(relations).value_counts()[4:50].to_dict()

# %%
relation_list = list(pd.Series(relations).value_counts()[4:50].to_dict().keys())
relation_list

# %%
relation_choice = "are"  #@param ['launches', 'is',  'on', 'makes', 'adds', 'improve', 'explains', 'optimize','get','use','update','introduces', 'expands','says','find','are','reveals','introduces new', 'make', 'know' ]

display_graph(relation_choice)

# %%
display_graph('moved')
